# %%
print("hello world")
# Out:
# hello world

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello world".upper())
"hello world".lower()
# Out:
# HELLO WORLD
# 'hello world'

# %%
"hello world".title()
# Out:
# 'Hello World'

# %%
"hello world".count('l')
# Out:
# 3

# %%
"hello world".replace('o','a')
# Out:
# 'hella warld'

# %%
message_1 = "I'm learning python from months"

# %%
message_1
# Out:
# "I'm learning python from months"

# %%
msg_2 = "and im still doing it!"

# %%
msg_2
# Out:
# 'and im still doing it!'

# %%
message_1 + msg_2
# Out:
# "I'm learning python from monthsand im still doing it!"

# %%
message_1 + ' ' + msg_2
# Out:
# "I'm learning python from months and im still doing it!"

# %%
message = message_1 + ' ' + msg_2
message
# Out:
# "I'm learning python from months and im still doing it!"

# %%
f'hello world'
# Out:
# 'hello world'

# %%
f'{message_1} cool {msg_2}'
# Out:
# "I'm learning python from months cool and im still doing it!"

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
print(countries[0])
# Out:
# United States

# %%
countries[-1]
# Out:
# 'Brazil'

# %%
countries[-4]
# Out:
# 'United States'

# %%
# slicing
last_name[start:stop]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # slicing
# ----> 2 last_name[start:stop]
#
# NameError: name 'last_name' is not defined

# %%
countries[0:3]

# %%
countries[0:1]

# %%
countries[1:]
# Out:
# ['India', 'China', 'Brazil']

# %%
countries[:2]
# Out:
# ['United States', 'India']

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
countries.append('Canada')
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries.insert(0, 'Spain')
countries
# Out:
# ['Spain', 'United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries_2 = ['UK', 'Germany', 'Austria']
countries + countries_2
# Out:
# ['Spain',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Canada',
#  'UK',
#  'Germany',
#  'Austria']

# %%
nested_list = [countries, countries_2]
nested_list
# Out:
# [['Spain', 'United States', 'India', 'China', 'Brazil', 'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %%
#countries = ['United States', 'India', 'China', 'Brazil']

# %%
countries.remove('United States')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 countries.remove('United States')
#
# ValueError: list.remove(x): x not in list

# %%
countries
# Out:
# ['India', 'China', 'Brazil']

# %%
countries.pop(-1)
# Out:
# 'Brazil'

# %%
countries
# Out:
# ['India', 'China']

# %%
del countries[0]
countries
# Out:
# ['China']

# %%
num = [1,2,6,8,4]

# %%
num.sort()
num
# Out:
# [1, 2, 4, 6, 8]

# %%
num = [1,2,6,8,4]
num.sort(reverse=True)
num
# Out:
# [8, 6, 4, 2, 1]

# %%
num[0] = 1000
num
# Out:
# [1000, 6, 4, 2, 1]

# %%
countries = ['United States', 'India', 'China', 'Brazil']
new_l = countries[:]
new_l
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
new_l2 = countries.copy()
new_l2
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
my_dict = {'key1':'value1', 'key2':'value2'}

# %%
my_data = {'name':'Frank', 'age':26}

# %%
my_data
# Out:
# {'name': 'Frank', 'age': 26}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Frank', 26])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Frank'), ('age', 26)])

# %%
my_data['height'] = 5.4
my_data
# Out:
# {'name': 'Frank', 'age': 26, 'height': 5.4}

# %%
my_data.update({'height':5.6})
my_data
# Out:
# {'name': 'Frank', 'age': 26, 'height': 5.6}

# %%
new_dict = my_data.copy()
new_dict
# Out:
# {'name': 'Frank', 'age': 26, 'height': 5.6}

# %%
new_dict_2 = my_data
new_dict_2
# Out:
# {'name': 'Frank', 'age': 26, 'height': 5.6}

# %%
my_data.pop('name')
# Out:
# 'Frank'

# %%
my_data
# Out:
# {'age': 26, 'height': 5.6}

# %%
del my_data['age']
my_data
# Out:
# {'height': 5.6}

# %%
my_data.clear()
my_data
# Out:
# {}

# %%
#if statement
age = 7

if age>=18:
    print("You're an adult!")
elif age>=13:
    print("You're a teenager")
else:
    print("You're a kid")
# Out:
# You're a kid

# %%
#for loop
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
for i, country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# United States
# 1
# India
# 2
# China
# 3
# Brazil

# %%
my_data = {'name':'Frank', 'age':20}
my_data
# Out:
# {'name': 'Frank', 'age': 20}

# %%
for key, value in my_data.items():
    print(key)
    print(value)
# Out:
# name
# Frank
# age
# 20

# %%
#function
def sum_values(a, b):
    x = a + b
    return x

# %%
sum_values(1,2)
# Out:
# 3

# %%
countries = ['United States', 'India', 'China', 'Brazil']

# %%
len(countries)
# Out:
# 4

# %%
max([10, 3, 56, 1, 99])
# Out:
# 99

# %%
min([12, 4, 67, 43, 9])
# Out:
# 4

# %%
type(countries)
# Out:
# list

# %%
for i in range(1, 10, 2):
     print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#module 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.cursor',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.spyder-py3',
#  '.Untitled14.ipynb.layout',
#  '.VirtualBox',
#  '.virtual_documents',
#  '.vscode',
#  'Ai  twin.ipynb',
#  'ai twin2.ipynb',
#  'anaconda3',
#  'Anaconda3_New',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'basicpython.ipynb',
#  'Contacts',
#  'Cookies',
#  'data',
#  'data type and use',
#  'datascience1.ipynb',
#  'Desktop',
#  'Downloads',
#  'exercise1.ipynb',
#  'Favorites',
#  'fun(Numpy).ipynb',
#  'games.ipynb',
#  'Jedi',
#  'Jupyternotebook.ipynb',
#  'Links',
#  'Local Settings',
#  'loops.ipynb',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'myfile.txt',
#  'names.csv',
#  'names.txt',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{9b22fa7f-cdf7-11ef-af95-98d6dbdc1247}.TM.blf',
# ...

# %%
os.makedirs("New Folder")

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.cursor',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.spyder-py3',
#  '.Untitled14.ipynb.layout',
#  '.VirtualBox',
#  '.virtual_documents',
#  '.vscode',
#  'Ai  twin.ipynb',
#  'ai twin2.ipynb',
#  'anaconda3',
#  'Anaconda3_New',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'basicpython.ipynb',
#  'Contacts',
#  'Cookies',
#  'data',
#  'data type and use',
#  'datascience1.ipynb',
#  'Desktop',
#  'Downloads',
#  'exercise1.ipynb',
#  'Favorites',
#  'fun(Numpy).ipynb',
#  'games.ipynb',
#  'Jedi',
#  'Jupyternotebook.ipynb',
#  'Links',
#  'Local Settings',
#  'loops.ipynb',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'myfile.txt',
#  'names.csv',
#  'names.txt',
#  'NetHood',
#  'New Folder',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{9b22fa7f-cdf7-11ef-af95-98d6dbdc1247}.TM.blf',
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #creating a dataframe from an array

# %% [markdown]
# ##option 1

# %%
#creating an array
data = np.array([[1,4], [2,5], [3,6]])

# %%
#creating a dataframe
pd.DataFrame(data)
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  6

# %%
#creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'],
             columns=['col1', 'col2'])

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
#option 2

# %%
#creating an array with list shape
data = [[1,4], [2,5], [3,6]]

# %%
#creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'],
             columns=['col1', 'col2'])

# %%
#showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
##creating a dataframe from a dictionary

# %%
#lists used in this
states = ['California', 'Texas', 'Florida', 'New York']
population = [34567898, 12398456, 65897263, 12345678]

# %%
#storing lists within a dictionary
dict_states = {'States':states, 'Population': population}

# %%
#creating the dataframe
df_population = pd.DataFrame(dict_states)

# %%
#showing the dataframe
df_population
# Out:
#        States  Population
# 0  California    34567898
# 1       Texas    12398456
# 2     Florida    65897263
# 3    New York    12345678

# %%
##creating a DataFrame from a csv file

# %%
#reading the csv file
pd.read_csv('StudentsPerformance.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 #reading the csv file
# ----> 2 pd.read_csv('StudentsPerformance.csv')
#
# File ~\Anaconda3_New\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
